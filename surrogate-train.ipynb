# %%
import pandas as pd

# %%
df = pd.read_csv("data/one-0010.dat", delim_whitespace=True, header=None, names=["nodenumber", "x-coordinate", "y-coordinate", "z-coordinate", "velocity-magnitude"], skiprows=1)
df
# Out:
#        nodenumber  x-coordinate  y-coordinate  z-coordinate  \
# 0               1     31.340762         0.508    -58.913215
# 1               2     29.588614         0.508    -57.901612
# 2               3     32.347197         0.508    -57.170018
# 3               4     27.841600         0.508    -56.892973
# 4               5     30.199386         0.508    -56.263283
# ...           ...           ...           ...           ...
# 78183       78184     31.887989         0.508    112.787967
# 78184       78185     35.138223         0.508    113.184725
# 78185       78186     30.632882         0.508    113.461806
# 78186       78187     33.391209         0.508    114.193364
# 78187       78188     31.639237         0.508    115.204865
#
#        velocity-magnitude
# 0                4.200751
# 1                4.200751
# 2                4.172021
# 3                4.200751
# 4                4.231397
# ...                   ...
# 78183            6.950213
# ...
